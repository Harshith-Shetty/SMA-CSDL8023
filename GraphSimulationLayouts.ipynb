# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.read_edgelist('Downloads/facebook_combined.txt')
nx.info(G)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_9948\966121627.py:4: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(G)
# 'Graph with 4039 nodes and 88234 edges'

# %%
nx.number_of_edges(G)
# Out:
# 88234

# %%
nx.number_of_nodes(G)
# Out:
# 4039

# %%
nx.is_directed(G)
# Out:
# False

# %%
G1=nx.read_pajek('Downloads/football.net')

# %%
nx.info(G1)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_9948\968434106.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(G1)
# 'MultiDiGraph with 35 nodes and 118 edges'

# %%
G2=nx.read_pajek('Downloads/karate.paj')
nx.info(G2)
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_9948\3463441975.py:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(G2)
# 'MultiGraph with 34 nodes and 78 edges'

# %%
G3=nx.read_gml('Downloads/karate.gml',label='id')
nx.draw(G3)

# %%
G1=nx.read_pajek('Downloads/football.net')      #Diplay Directed Graph

# %%
nx.draw_circular(G1)

# %%
nx.draw_spectral(G1)

# %%
nx.draw_random(G1)

# %%
nx.draw_kamada_kawai(G1)

# %%
nx.draw_spring(G1)

# %%
nx.draw_shell(G1)

# %%
nx.degree(G3)    #Degree of each Node
# Out:
# DegreeView({1: 16, 2: 9, 3: 10, 4: 6, 5: 3, 6: 4, 7: 4, 8: 4, 9: 5, 10: 2, 11: 3, 12: 1, 13: 2, 14: 5, 15: 2, 16: 2, 17: 2, 18: 2, 19: 2, 20: 3, 21: 2, 22: 2, 23: 2, 24: 5, 25: 3, 26: 3, 27: 2, 28: 4, 29: 3, 30: 4, 31: 4, 32: 6, 33: 12, 34: 17})

# %%
degrees = [val for (node, val) in G3.degree()]

# %%
list(set(degrees))     #Unique Degrees of Nodes
# Out:
# [1, 2, 3, 4, 5, 6, 9, 10, 12, 16, 17]

# %%
def plot_deg_dist(G):
    all_degrees=[val for (node, val) in G3.degree()]
    unique_degrees=list(set(all_degrees))
    count_of_degrees=[]
    for i in unique_degrees:
        x= all_degrees.count(i)
        count_of_degrees.append(x)
    plt.plot(unique_degrees,count_of_degrees,'yo-')
    plt.xlabel('Degrees')
    plt.ylabel('Number of Nodes')
    plt.title('Degree Distribution of Karate Network')
    plt.show()

# %%
plot_deg_dist(G3)   #Degree Distribution Ploting for karate data set

# %%
nx.density(G3)
# Out:
# 0.13903743315508021
